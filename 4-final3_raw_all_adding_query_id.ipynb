# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Lab/ODoH-ML/missouri-third-round-24nov/2/

# %ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Lab/ODoH-ML/missouri-third-round-24nov/2
# final2.csv                  MEREGED_RAW_FINAL.csv
# final3_cleaned.csv          MEREGED_RAW_FINAL_GROUPED.csv
# final3_cleaned_grouped.csv  missouri_third_round_part_22_nov_24.pcap
# final3.csv                  target_proxy.csv
# final4.csv                  target_resolver.csv
# final.csv                   test4_target_proxy.pcap

# %%
import pandas as pd
# ds_1 = pd.read_csv("1/final3_cleaned.csv")
# ds_2 = pd.read_csv("2/final3_cleaned.csv")
# ds_3 = pd.read_csv("3/final3_cleaned.csv")
# ds_4 = pd.read_csv("4/final3_cleaned.csv")
# ds_5 = pd.read_csv("5/final3_cleaned.csv")
# ds_6 = pd.read_csv("6/final3_cleaned.csv")

ds_6 = pd.read_csv("final3_cleaned.csv")

# ds_1.info()
# ds_2.info()
# ds_3.info()
# ds_4.info()
# ds_5.info()

# %%
ds_temp = [ds_6]
  
ds = pd.concat(ds_temp,ignore_index=True)
ds
ds = ds.iloc[: , 1:]
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1297 entries, 0 to 1296
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   sub_query                    1297 non-null   object
#  1   query                        1297 non-null   object
#  2   Input-U-Time                 1297 non-null   float64
#  3   Input-D-Time                 1297 non-null   float64
#  4   Input-D-Size                 1297 non-null   float64
#  5   Input-U-Size                 1297 non-null   float64
#  6   Resolver in Target-Resolver  1297 non-null   object
#  7   Out-U-Time                   1297 non-null   float64
#  8   Out-D-Time                   1297 non-null   float64
#  9   Out-D-Size                   1297 non-null   float64
#  10  Out-U-Size                   1297 non-null   float64
# dtypes: float64(8), object(3)
# memory usage: 111.6+ KB

# %%
ds.head(30)
# Out:
#                                             sub_query  \
# 0   client-mo.test3.ch-geni-net.instageni.rnet.mis...
# 1   client-mo.test3.ch-geni-net.instageni.rnet.mis...
# 2   client-mo.test3.ch-geni-net.instageni.rnet.mis...
# 3   client-mo.test3.ch-geni-net.instageni.rnet.mis...
# 4   client-mo.test3.ch-geni-net.instageni.rnet.mis...
# 5                                   www.wikimedia.org
# 6                                   www.wikimedia.org
# 7                            foundation.wikimedia.org
# 8                            foundation.wikimedia.org
# 9                                   www.wikimedia.org
# 10                                  www.wikimedia.org
# 11                                      wikimedia.org
# 12                                      wikimedia.org
# 13                                  www.wikimedia.org
# 14                                  www.wikimedia.org
# 15                               upload.wikimedia.org
# ...

# %%
ds.loc[1,'sub_query']
# Out:
# 'client-mo.test3.ch-geni-net.instageni.rnet.missouri.edu'

# %%
for i in range(len(ds['sub_query'])):
  if(ds.loc[i, 'query'] == 'client-mo.test3.ch-geni-net.instageni.rnet.missouri.edu'):
    ds.loc[i,'query'] = ds.loc[i,'sub_query']

# %%
for i in range(len(ds['sub_query'])):
  if(ds.loc[i, 'query'] == 'client-mo.test3.ch-geni-net.instageni.rnet.missouri.edu'):
    ds = ds.drop(index=[i])

ds = ds.reset_index(drop=True)
ds
# Out:
#                           sub_query                     query  Input-U-Time  \
# 0                 www.wikimedia.org         www.wikimedia.org      0.177221
# 1                 www.wikimedia.org         www.wikimedia.org      0.069576
# 2          foundation.wikimedia.org  foundation.wikimedia.org      0.291711
# 3          foundation.wikimedia.org  foundation.wikimedia.org      0.000058
# 4                 www.wikimedia.org         www.wikimedia.org      0.340998
# ...                             ...                       ...           ...
# 1287           fonts.googleapis.com              blogspot.com      0.001590
# 1288              fonts.gstatic.com              blogspot.com      0.367031
# 1289              fonts.gstatic.com              blogspot.com      0.001537
# 1290  blogger.googleusercontent.com              blogspot.com      0.344038
# 1291  blogger.googleusercontent.com              blogspot.com      0.002398
#
# ...

# %%
ds.head(5)
# Out:
#                   sub_query                     query  Input-U-Time  \
# 0         www.wikimedia.org         www.wikimedia.org      0.177221
# 1         www.wikimedia.org         www.wikimedia.org      0.069576
# 2  foundation.wikimedia.org  foundation.wikimedia.org      0.291711
# 3  foundation.wikimedia.org  foundation.wikimedia.org      0.000058
# 4         www.wikimedia.org         www.wikimedia.org      0.340998
#
#    Input-D-Time  Input-D-Size  Input-U-Size Resolver in Target-Resolver  \
# 0      0.044645         170.0         135.0                     8.8.8.8
# 1      0.149511         182.0         135.0                     9.9.9.9
# 2      0.102120         184.0         142.0                     8.8.8.8
# 3      0.008335         196.0         142.0                     1.1.1.1
# 4      0.003940         170.0         135.0                     8.8.8.8
#
#    Out-U-Time  Out-D-Time  Out-D-Size  Out-U-Size
# 0    0.000353    0.038791        81.0        46.0
# ...

# %%
# %ls
# Out:
# final2.csv                  MEREGED_RAW_FINAL.csv
# final3_cleaned.csv          MEREGED_RAW_FINAL_GROUPED.csv
# final3_cleaned_grouped.csv  missouri_third_round_part_22_nov_24.pcap
# final3.csv                  target_proxy.csv
# final4.csv                  target_resolver.csv
# final.csv                   test4_target_proxy.pcap

# %%
ds_updated = ds
ds_updated.head(10)
# Out:
#                   sub_query                     query  Input-U-Time  \
# 0         www.wikimedia.org         www.wikimedia.org      0.177221
# 1         www.wikimedia.org         www.wikimedia.org      0.069576
# 2  foundation.wikimedia.org  foundation.wikimedia.org      0.291711
# 3  foundation.wikimedia.org  foundation.wikimedia.org      0.000058
# 4         www.wikimedia.org         www.wikimedia.org      0.340998
# 5         www.wikimedia.org         www.wikimedia.org      0.001666
# 6             wikimedia.org             wikimedia.org      0.309575
# 7             wikimedia.org             wikimedia.org      0.001502
# 8         www.wikimedia.org         www.wikimedia.org      0.267766
# 9         www.wikimedia.org         www.wikimedia.org      0.002491
#
#    Input-D-Time  Input-D-Size  Input-U-Size Resolver in Target-Resolver  \
# 0      0.044645         170.0         135.0                     8.8.8.8
# 1      0.149511         182.0         135.0                     9.9.9.9
# ...

# %%
# from sklearn import preprocessing

# le = preprocessing.LabelEncoder()
# le.fit(ds[['query']])

# ds_updated['query_id'] = le.transform(ds[['query']])

# %%
import pandas as pd

# Load dataset file
domains_alphabet_unique = list(ds['query'].unique())
domains_alphabet = ds['query']

domains_number = []

for i in range(len(domains_alphabet)):
  if(domains_alphabet[i] in domains_alphabet_unique):
   key = domains_alphabet[i]
   domains_number.append(domains_alphabet_unique.index(key))
  # print(domains_alphabet_unique.index(key))


# domains_number
print(len(domains_number))
print((domains_alphabet_unique))
# Out:
# 1292
# ['www.wikimedia.org', 'foundation.wikimedia.org', 'wikimedia.org', 'upload.wikimedia.org', 'xhamster.com', 'target.com', 'roblox.com', 'foxnews.com', 'search-hub.co', 'espn.com', 'zoom.us', 'adobe.com', 'affirm.com', 'chase.com', 'mcdonalds.com', 'onlyfans.com', 'healthline.com', 'chaturbate.com', 'instructure.com', 'criteo.com', 'homedepot.com', 'qccerttest.com', 'samsung.com', 'yelp.com', 'craigslist.org', 'att.com', 'evergage.com', 'tumblr.com', 'bestbuy.com', 'verizon.com', 'ups.com', 'msn.com', 'mangago.me', 'mangakakalot.com', 'doordash.com', 'force.com', 'fedex.com', 'ticketmaster.com', 'doppiocdn.net', 'tripadvisor.com', 't-mobile.com', 'capitalone.com', 'impactcdn.com', 'wellsfargo.com', 'doppiocdn.com', 'dropbox.com', 'uber.com', 'salesforce.com', 'cvs.com', 'shopify.com', 'okta.com', 'airbnb.com', 'expedia.com', 'safedk.com', 'dailymail.co.uk', 'uidapi.com', 'instacart.com', 'patreon.com', 'wordpress.com', 'blogspot.com']

# %%
ds_updated['query_id'] = domains_number

# %%
ds_updated.head(5)
# Out:
#                   sub_query                     query  Input-U-Time  \
# 0         www.wikimedia.org         www.wikimedia.org      0.177221
# 1         www.wikimedia.org         www.wikimedia.org      0.069576
# 2  foundation.wikimedia.org  foundation.wikimedia.org      0.291711
# 3  foundation.wikimedia.org  foundation.wikimedia.org      0.000058
# 4         www.wikimedia.org         www.wikimedia.org      0.340998
#
#    Input-D-Time  Input-D-Size  Input-U-Size Resolver in Target-Resolver  \
# 0      0.044645         170.0         135.0                     8.8.8.8
# 1      0.149511         182.0         135.0                     9.9.9.9
# 2      0.102120         184.0         142.0                     8.8.8.8
# 3      0.008335         196.0         142.0                     1.1.1.1
# 4      0.003940         170.0         135.0                     8.8.8.8
#
#    Out-U-Time  Out-D-Time  Out-D-Size  Out-U-Size  query_id
# 0    0.000353    0.038791        81.0        46.0         0
# ...

# %%
ds_updated.to_csv('MEREGED_RAW_FINAL.csv')
ds_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1292 entries, 0 to 1291
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   sub_query                    1292 non-null   object
#  1   query                        1292 non-null   object
#  2   Input-U-Time                 1292 non-null   float64
#  3   Input-D-Time                 1292 non-null   float64
#  4   Input-D-Size                 1292 non-null   float64
#  5   Input-U-Size                 1292 non-null   float64
#  6   Resolver in Target-Resolver  1292 non-null   object
#  7   Out-U-Time                   1292 non-null   float64
#  8   Out-D-Time                   1292 non-null   float64
#  9   Out-D-Size                   1292 non-null   float64
#  10  Out-U-Size                   1292 non-null   float64
#  11  query_id                     1292 non-null   int64
# dtypes: float64(8), int64(1), object(3)
# ...

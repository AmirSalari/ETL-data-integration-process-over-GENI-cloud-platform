# %%
from google.colab import drive
# Mount google drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Lab/ODoH-ML/missouri-third-round-24nov/

# %ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Lab/ODoH-ML/missouri-third-round-24nov
# 1/  2/

# %%
import pandas as pd
ds_1_grouped = pd.read_csv("1/MEREGED_RAW_FINAL_GROUPED.csv")
ds_2_grouped = pd.read_csv("2/MEREGED_RAW_FINAL_GROUPED.csv")
# ds_3_grouped = pd.read_csv("3/MEREGED_RAW_FINAL_GROUPED.csv")
# ds_4_grouped = pd.read_csv("4/MEREGED_RAW_FINAL_GROUPED.csv")
# ds_5_grouped = pd.read_csv("5/MEREGED_RAW_FINAL_GROUPED.csv")
# ds_6_grouped = pd.read_csv("6/MEREGED_RAW_FINAL_GROUPED.csv")


ds_1 = pd.read_csv("1/MEREGED_RAW_FINAL.csv")
ds_2 = pd.read_csv("2/MEREGED_RAW_FINAL.csv")
# ds_3 = pd.read_csv("3/MEREGED_RAW_FINAL.csv")
# ds_4 = pd.read_csv("4/MEREGED_RAW_FINAL.csv")
# ds_5 = pd.read_csv("5/MEREGED_RAW_FINAL.csv")
# ds_6 = pd.read_csv("6/MEREGED_RAW_FINAL.csv")

ds_2_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        57 non-null     int64
#  1   query             57 non-null     object
#  2   sum Input-U-Time  57 non-null     float64
#  3   sum Input-D-Time  57 non-null     float64
#  4   sum Input-U-Size  57 non-null     float64
#  5   sum Input-D-Size  57 non-null     float64
#  6   sum Out-U-Time    57 non-null     float64
#  7   sum Out-D-Time    57 non-null     float64
#  8   sum Out-U-Size    57 non-null     float64
#  9   sum Out-D-Size    57 non-null     float64
#  10  count             57 non-null     int64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 5.0+ KB

# %%
ds_temp_grouped = [ds_1_grouped, ds_2_grouped]
ds_temp = [ds_1, ds_2]

ds_grouped = pd.concat(ds_temp_grouped,ignore_index=True)
ds = pd.concat(ds_temp,ignore_index=True)

ds.head(5)
# Out:
#    Unnamed: 0       sub_query           query  Input-U-Time  Input-D-Time  \
# 0           0  www.google.com  www.google.com      0.170264      0.013562
# 1           1  www.google.com  www.google.com      0.069064      0.015266
# 2           2  www.google.com  www.google.com      0.000029      0.004247
# 3           3  www.google.com  www.google.com      0.005367      0.006429
# 4           4  www.google.com  www.google.com      0.359707      0.006643
#
#    Input-D-Size  Input-U-Size Resolver in Target-Resolver  Out-U-Time  \
# 0         114.0         132.0                     8.8.8.8    0.000269
# 1         126.0         132.0                     9.9.9.9    0.003120
# 2         114.0         132.0                     8.8.8.8    0.000430
# 3         126.0         132.0                     1.1.1.1    0.000272
# 4         114.0         132.0                     9.9.9.9    0.000441
#
#    Out-D-Time  Out-D-Size  Out-U-Size  query_id
# 0    0.008038        59.0        43.0         0
# ...

# %%
# %ls /content/drive/MyDrive/Lab/ODoH-ML/NOVEMBER-100-TOP-ALEXA/
# Out:
# georgia/   seattle/  THE-LAST.csv          wisconsin/
# missouri/  texas/    THE-LAST-GROUPED.csv

# %%
ds_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        99 non-null     int64
#  1   query             99 non-null     object
#  2   sum Input-U-Time  99 non-null     float64
#  3   sum Input-D-Time  99 non-null     float64
#  4   sum Input-U-Size  99 non-null     float64
#  5   sum Input-D-Size  99 non-null     float64
#  6   sum Out-U-Time    99 non-null     float64
#  7   sum Out-D-Time    99 non-null     float64
#  8   sum Out-U-Size    99 non-null     float64
#  9   sum Out-D-Size    99 non-null     float64
#  10  count             99 non-null     int64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 8.6+ KB

# %%
print(len(ds_grouped['query'].unique()))
print(len(ds['query'].unique()))
# Out:
# 99
# 102

# %%
ds_grouped.to_csv('/content/drive/MyDrive/Lab/ODoH-ML/NOVEMBER-100-TOP-ALEXA/missouri/NOV-25-ALL-GROUPED-MEREGED-missouri-third.csv')
ds.to_csv('/content/drive/MyDrive/Lab/ODoH-ML/NOVEMBER-100-TOP-ALEXA/missouri/NOV-25-ALL-MEREGED-missouri-third.csv')

# %%
# %ls /content/drive/MyDrive/Lab/ODoH-ML/NOVEMBER-100-TOP-ALEXA/
# Out:
# georgia/   seattle/  THE-LAST.csv          wisconsin/
# missouri/  texas/    THE-LAST-GROUPED.csv
